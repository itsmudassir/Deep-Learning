# %%
import warnings
warnings.filterwarnings('ignore')

import keras
from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
(x_train,y_train),(x_test,y_test)=cifar10.load_data()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure(figsize=(20,5))

for i in range(30):
    ax = fig.add_subplot(3,12,i+1,xticks=[],yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %%
x_train = x_train.astype('float32')/255
x_test= x_test.astype('float32')/255

# %%
from keras.utils import np_utils

num_classes= len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train,num_classes)
y_test = keras.utils.to_categorical(y_test,num_classes)

(x_train,x_valid) = x_train[5000:],x_train[:5000]
(y_train,y_valid) = y_train[5000:],y_train[:5000]

# %%
print("x trianing set shape : " ,x_train.shape)
print("x trian samples : " ,x_train.shape[0])
print("x test samples : " ,x_test.shape[0])
print("x valid samples : " ,x_valid.shape[0])
# Out:
# x trianing set shape :  (45000, 32, 32, 3)
# x trian samples :  45000
# x test samples :  10000
# x valid samples :  5000

# %% [markdown]
# # Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D, Flatten, Dense, Dropout

# %%
model = Sequential()
model.add(Conv2D(filters=16,kernel_size=2, padding='same', activation='relu', 
                 input_shape=(32,32,3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32,kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64,kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500,activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10,activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath = 'model.weights.best.hdfs',verbose=1,save_best_only=True)

# %%
hist = model.fit(x_train,y_train,batch_size=32,epochs=100,
                validation_data=(x_valid,y_valid), callbacks=[checkpointer],
                verbose=2,shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 19s - loss: 1.5890 - acc: 0.4221 - val_loss: 1.3041 - val_acc: 0.5226
#
# Epoch 00001: val_loss improved from inf to 1.30415, saving model to model.weights.best.hdfs
# Epoch 2/100
#  - 5s - loss: 1.2592 - acc: 0.5501 - val_loss: 1.1266 - val_acc: 0.5960
#
# Epoch 00002: val_loss improved from 1.30415 to 1.12664, saving model to model.weights.best.hdfs
# Epoch 3/100
#  - 5s - loss: 1.1371 - acc: 0.5979 - val_loss: 1.0942 - val_acc: 0.6078
#
# Epoch 00003: val_loss improved from 1.12664 to 1.09419, saving model to model.weights.best.hdfs
# Epoch 4/100
#  - 5s - loss: 1.0655 - acc: 0.6257 - val_loss: 1.0308 - val_acc: 0.6318
#
# Epoch 00004: val_loss improved from 1.09419 to 1.03080, saving model to model.weights.best.hdfs
# Epoch 5/100
#  - 5s - loss: 1.0245 - acc: 0.6444 - val_loss: 1.0007 - val_acc: 0.6598
#
# Epoch 00005: val_loss improved from 1.03080 to 1.00073, saving model to model.weights.best.hdfs
# Epoch 6/100
#  - 5s - loss: 1.0090 - acc: 0.6509 - val_loss: 1.0518 - val_acc: 0.6600
#
# Epoch 00006: val_loss did not improve from 1.00073
# Epoch 7/100
#  - 5s - loss: 0.9963 - acc: 0.6597 - val_loss: 0.9620 - val_acc: 0.6676
#
# Epoch 00007: val_loss improved from 1.00073 to 0.96202, saving model to model.weights.best.hdfs
# Epoch 8/100
#  - 5s - loss: 0.9932 - acc: 0.6631 - val_loss: 0.9769 - val_acc: 0.6760
#
# Epoch 00008: val_loss did not improve from 0.96202
# Epoch 9/100
#  - 5s - loss: 0.9958 - acc: 0.6616 - val_loss: 1.0243 - val_acc: 0.6672
#
# Epoch 00009: val_loss did not improve from 0.96202
# Epoch 10/100
#  - 5s - loss: 1.0055 - acc: 0.6594 - val_loss: 0.9870 - val_acc: 0.6784
#
# Epoch 00010: val_loss did not improve from 0.96202
# Epoch 11/100
#  - 5s - loss: 1.0235 - acc: 0.6579 - val_loss: 1.0336 - val_acc: 0.6492
#
# Epoch 00011: val_loss did not improve from 0.96202
# Epoch 12/100
#  - 5s - loss: 1.0381 - acc: 0.6561 - val_loss: 1.5008 - val_acc: 0.5800
#
# Epoch 00012: val_loss did not improve from 0.96202
# Epoch 13/100
#  - 5s - loss: 1.0523 - acc: 0.6484 - val_loss: 0.9607 - val_acc: 0.6692
#
# Epoch 00013: val_loss improved from 0.96202 to 0.96073, saving model to model.weights.best.hdfs
# Epoch 14/100
#  - 5s - loss: 1.0759 - acc: 0.6435 - val_loss: 1.0671 - val_acc: 0.6518
#
# Epoch 00014: val_loss did not improve from 0.96073
# Epoch 15/100
#  - 5s - loss: 1.0941 - acc: 0.6366 - val_loss: 1.2394 - val_acc: 0.6012
#
# Epoch 00015: val_loss did not improve from 0.96073
# Epoch 16/100
#  - 5s - loss: 1.1111 - acc: 0.6316 - val_loss: 1.0803 - val_acc: 0.6592
#
# Epoch 00016: val_loss did not improve from 0.96073
# Epoch 17/100
#  - 5s - loss: 1.1347 - acc: 0.6254 - val_loss: 1.0701 - val_acc: 0.6618
#
# Epoch 00017: val_loss did not improve from 0.96073
# Epoch 18/100
#  - 5s - loss: 1.1472 - acc: 0.6212 - val_loss: 1.0496 - val_acc: 0.6412
#
# Epoch 00018: val_loss did not improve from 0.96073
# Epoch 19/100
#  - 5s - loss: 1.1579 - acc: 0.6142 - val_loss: 1.3126 - val_acc: 0.5968
#
# Epoch 00019: val_loss did not improve from 0.96073
# Epoch 20/100
#  - 5s - loss: 1.1711 - acc: 0.6156 - val_loss: 1.0206 - val_acc: 0.6542
#
# Epoch 00020: val_loss did not improve from 0.96073
# Epoch 21/100
#  - 5s - loss: 1.1873 - acc: 0.6097 - val_loss: 1.2390 - val_acc: 0.6252
#
# Epoch 00021: val_loss did not improve from 0.96073
# Epoch 22/100
#  - 5s - loss: 1.1992 - acc: 0.6021 - val_loss: 1.2436 - val_acc: 0.6264
#
# Epoch 00022: val_loss did not improve from 0.96073
# Epoch 23/100
#  - 5s - loss: 1.2173 - acc: 0.5981 - val_loss: 1.1766 - val_acc: 0.6144
#
# Epoch 00023: val_loss did not improve from 0.96073
# Epoch 24/100
#  - 5s - loss: 1.2376 - acc: 0.5910 - val_loss: 1.1005 - val_acc: 0.6210
#
# Epoch 00024: val_loss did not improve from 0.96073
# Epoch 25/100
#  - 5s - loss: 1.2623 - acc: 0.5864 - val_loss: 1.0772 - val_acc: 0.6258
#
# Epoch 00025: val_loss did not improve from 0.96073
# Epoch 26/100
#  - 5s - loss: 1.2637 - acc: 0.5816 - val_loss: 1.1745 - val_acc: 0.5906
#
# Epoch 00026: val_loss did not improve from 0.96073
# Epoch 27/100
#  - 5s - loss: 1.2679 - acc: 0.5786 - val_loss: 1.2825 - val_acc: 0.6012
#
# Epoch 00027: val_loss did not improve from 0.96073
# Epoch 28/100
#  - 5s - loss: 1.2800 - acc: 0.5777 - val_loss: 1.2231 - val_acc: 0.6008
#
# Epoch 00028: val_loss did not improve from 0.96073
# Epoch 29/100
#  - 5s - loss: 1.3107 - acc: 0.5693 - val_loss: 1.3848 - val_acc: 0.5606
#
# Epoch 00029: val_loss did not improve from 0.96073
# Epoch 30/100
#  - 5s - loss: 1.3228 - acc: 0.5636 - val_loss: 1.3718 - val_acc: 0.5238
#
# Epoch 00030: val_loss did not improve from 0.96073
# Epoch 31/100
#  - 5s - loss: 1.3252 - acc: 0.5652 - val_loss: 1.1833 - val_acc: 0.6036
#
# Epoch 00031: val_loss did not improve from 0.96073
# Epoch 32/100
#  - 5s - loss: 1.3458 - acc: 0.5534 - val_loss: 1.5685 - val_acc: 0.5496
#
# Epoch 00032: val_loss did not improve from 0.96073
# Epoch 33/100
#  - 5s - loss: 1.3696 - acc: 0.5440 - val_loss: 1.2460 - val_acc: 0.5796
#
# Epoch 00033: val_loss did not improve from 0.96073
# Epoch 34/100
#  - 5s - loss: 1.3985 - acc: 0.5346 - val_loss: 1.2106 - val_acc: 0.5998
#
# Epoch 00034: val_loss did not improve from 0.96073
# Epoch 35/100
#  - 5s - loss: 1.4126 - acc: 0.5295 - val_loss: 1.3120 - val_acc: 0.5608
#
# Epoch 00035: val_loss did not improve from 0.96073
# Epoch 36/100
#  - 5s - loss: 1.4418 - acc: 0.5199 - val_loss: 1.2193 - val_acc: 0.5848
#
# Epoch 00036: val_loss did not improve from 0.96073
# Epoch 37/100
#  - 5s - loss: 1.4753 - acc: 0.5061 - val_loss: 1.3524 - val_acc: 0.5344
#
# Epoch 00037: val_loss did not improve from 0.96073
# Epoch 38/100
#  - 5s - loss: 1.4820 - acc: 0.5067 - val_loss: 1.2912 - val_acc: 0.5524
#
# Epoch 00038: val_loss did not improve from 0.96073
# Epoch 39/100
#  - 5s - loss: 1.5021 - acc: 0.5016 - val_loss: 1.3638 - val_acc: 0.5360
#
# Epoch 00039: val_loss did not improve from 0.96073
# Epoch 40/100
#  - 5s - loss: 1.4924 - acc: 0.5018 - val_loss: 1.5814 - val_acc: 0.4672
#
# Epoch 00040: val_loss did not improve from 0.96073
# Epoch 41/100
#  - 5s - loss: 1.5157 - acc: 0.4923 - val_loss: 1.3683 - val_acc: 0.4988
#
# Epoch 00041: val_loss did not improve from 0.96073
# Epoch 42/100
#  - 5s - loss: 1.5306 - acc: 0.4889 - val_loss: 1.4339 - val_acc: 0.4980
#
# Epoch 00042: val_loss did not improve from 0.96073
# Epoch 43/100
#  - 5s - loss: 1.5390 - acc: 0.4832 - val_loss: 1.5085 - val_acc: 0.5298
#
# Epoch 00043: val_loss did not improve from 0.96073
# Epoch 44/100
#  - 5s - loss: 1.5616 - acc: 0.4756 - val_loss: 1.4220 - val_acc: 0.4972
#
# Epoch 00044: val_loss did not improve from 0.96073
# Epoch 45/100
#  - 5s - loss: 1.5567 - acc: 0.4831 - val_loss: 1.5459 - val_acc: 0.4550
#
# Epoch 00045: val_loss did not improve from 0.96073
# Epoch 46/100
#  - 5s - loss: 1.5673 - acc: 0.4746 - val_loss: 1.4270 - val_acc: 0.5024
#
# Epoch 00046: val_loss did not improve from 0.96073
# Epoch 47/100
#  - 5s - loss: 1.5660 - acc: 0.4746 - val_loss: 1.2322 - val_acc: 0.5518
#
# Epoch 00047: val_loss did not improve from 0.96073
# Epoch 48/100
#  - 5s - loss: 1.5830 - acc: 0.4676 - val_loss: 1.3640 - val_acc: 0.5244
#
# Epoch 00048: val_loss did not improve from 0.96073
# Epoch 49/100
#  - 5s - loss: 1.5927 - acc: 0.4629 - val_loss: 1.6837 - val_acc: 0.4008
#
# Epoch 00049: val_loss did not improve from 0.96073
# Epoch 50/100
#  - 5s - loss: 1.6054 - acc: 0.4595 - val_loss: 1.6869 - val_acc: 0.4310
#
# Epoch 00050: val_loss did not improve from 0.96073
# Epoch 51/100
#  - 5s - loss: 1.6121 - acc: 0.4536 - val_loss: 1.4216 - val_acc: 0.4840
#
# Epoch 00051: val_loss did not improve from 0.96073
# Epoch 52/100
#  - 5s - loss: 1.6225 - acc: 0.4519 - val_loss: 1.5858 - val_acc: 0.4808
#
# Epoch 00052: val_loss did not improve from 0.96073
# Epoch 53/100
#  - 5s - loss: 1.6130 - acc: 0.4507 - val_loss: 1.4406 - val_acc: 0.4842
#
# Epoch 00053: val_loss did not improve from 0.96073
# Epoch 54/100
#  - 5s - loss: 1.6046 - acc: 0.4527 - val_loss: 1.3588 - val_acc: 0.4954
#
# Epoch 00054: val_loss did not improve from 0.96073
# Epoch 55/100
#  - 5s - loss: 1.6093 - acc: 0.4514 - val_loss: 1.3149 - val_acc: 0.5392
#
# Epoch 00055: val_loss did not improve from 0.96073
# Epoch 56/100
#  - 5s - loss: 1.6029 - acc: 0.4529 - val_loss: 1.3505 - val_acc: 0.5192
#
# Epoch 00056: val_loss did not improve from 0.96073
# Epoch 57/100
#  - 5s - loss: 1.6160 - acc: 0.4526 - val_loss: 1.3144 - val_acc: 0.5306
#
# Epoch 00057: val_loss did not improve from 0.96073
# Epoch 58/100
#  - 5s - loss: 1.6317 - acc: 0.4449 - val_loss: 1.4490 - val_acc: 0.5038
# Epoch 00058: val_loss did not improve from 0.96073
# Epoch 59/100
#  - 5s - loss: 1.6311 - acc: 0.4439 - val_loss: 1.6094 - val_acc: 0.4246
#
# Epoch 00059: val_loss did not improve from 0.96073
# Epoch 60/100
#  - 5s - loss: 1.6404 - acc: 0.4432 - val_loss: 1.4054 - val_acc: 0.5054
#
# Epoch 00060: val_loss did not improve from 0.96073
# Epoch 61/100
#  - 5s - loss: 1.6480 - acc: 0.4398 - val_loss: 1.5990 - val_acc: 0.4410
#
# Epoch 00061: val_loss did not improve from 0.96073
# Epoch 62/100
#  - 5s - loss: 1.6591 - acc: 0.4360 - val_loss: 1.4940 - val_acc: 0.5102
#
# Epoch 00062: val_loss did not improve from 0.96073
# Epoch 63/100
#  - 5s - loss: 1.6627 - acc: 0.4362 - val_loss: 1.4053 - val_acc: 0.4852
#
# Epoch 00063: val_loss did not improve from 0.96073
# Epoch 64/100
#  - 5s - loss: 1.6616 - acc: 0.4339 - val_loss: 1.5552 - val_acc: 0.4342
#
# Epoch 00064: val_loss did not improve from 0.96073
# Epoch 65/100
#  - 5s - loss: 1.6647 - acc: 0.4322 - val_loss: 1.5805 - val_acc: 0.4422
#
# Epoch 00065: val_loss did not improve from 0.96073
# Epoch 66/100
#  - 5s - loss: 1.6880 - acc: 0.4270 - val_loss: 1.9155 - val_acc: 0.3856
#
# Epoch 00066: val_loss did not improve from 0.96073
# Epoch 67/100
#  - 5s - loss: 1.6787 - acc: 0.4248 - val_loss: 1.4868 - val_acc: 0.4824
#
# Epoch 00067: val_loss did not improve from 0.96073
# Epoch 68/100
#  - 5s - loss: 1.6823 - acc: 0.4234 - val_loss: 1.4801 - val_acc: 0.4958
#
# Epoch 00068: val_loss did not improve from 0.96073
# Epoch 69/100
#  - 5s - loss: 1.6989 - acc: 0.4197 - val_loss: 1.5940 - val_acc: 0.4486
#
# Epoch 00069: val_loss did not improve from 0.96073
# Epoch 70/100
#  - 5s - loss: 1.6981 - acc: 0.4179 - val_loss: 1.4670 - val_acc: 0.4768
#
# Epoch 00070: val_loss did not improve from 0.96073
# Epoch 71/100
#  - 5s - loss: 1.7032 - acc: 0.4187 - val_loss: 1.3703 - val_acc: 0.5222
#
# Epoch 00071: val_loss did not improve from 0.96073
# Epoch 72/100
#  - 5s - loss: 1.6957 - acc: 0.4166 - val_loss: 1.5350 - val_acc: 0.4298
#
# Epoch 00072: val_loss did not improve from 0.96073
# Epoch 73/100
#  - 5s - loss: 1.6998 - acc: 0.4140 - val_loss: 1.5060 - val_acc: 0.4476
#
# Epoch 00073: val_loss did not improve from 0.96073
# Epoch 74/100
#  - 5s - loss: 1.7167 - acc: 0.4106 - val_loss: 1.5823 - val_acc: 0.4562
#
# Epoch 00074: val_loss did not improve from 0.96073
# Epoch 75/100
#  - 5s - loss: 1.7422 - acc: 0.4027 - val_loss: 1.6892 - val_acc: 0.4372
#
# Epoch 00075: val_loss did not improve from 0.96073
# Epoch 76/100
#  - 5s - loss: 1.7426 - acc: 0.4007 - val_loss: 1.5448 - val_acc: 0.4638
#
# Epoch 00076: val_loss did not improve from 0.96073
# Epoch 77/100
#  - 5s - loss: 1.7603 - acc: 0.4001 - val_loss: 1.4852 - val_acc: 0.4672
#
# Epoch 00077: val_loss did not improve from 0.96073
# Epoch 78/100
#  - 5s - loss: 1.7662 - acc: 0.3878 - val_loss: 1.5855 - val_acc: 0.4588
#
# Epoch 00078: val_loss did not improve from 0.96073
# Epoch 79/100
#  - 5s - loss: 1.7601 - acc: 0.3936 - val_loss: 1.6916 - val_acc: 0.3936
#
# Epoch 00079: val_loss did not improve from 0.96073
# Epoch 80/100
#  - 5s - loss: 1.7586 - acc: 0.3902 - val_loss: 1.4439 - val_acc: 0.5094
#
# Epoch 00080: val_loss did not improve from 0.96073
# Epoch 81/100
#  - 5s - loss: 1.7629 - acc: 0.3913 - val_loss: 1.4680 - val_acc: 0.4708
#
# Epoch 00081: val_loss did not improve from 0.96073
# Epoch 82/100
#  - 5s - loss: 1.7644 - acc: 0.3954 - val_loss: 1.5643 - val_acc: 0.4516
#
# Epoch 00082: val_loss did not improve from 0.96073
# Epoch 83/100
#  - 5s - loss: 1.7435 - acc: 0.3940 - val_loss: 1.9641 - val_acc: 0.3578
#
# Epoch 00083: val_loss did not improve from 0.96073
# Epoch 84/100
#  - 5s - loss: 1.7461 - acc: 0.3950 - val_loss: 1.6210 - val_acc: 0.4112
#
# Epoch 00084: val_loss did not improve from 0.96073
# Epoch 85/100
#  - 5s - loss: 1.7671 - acc: 0.3901 - val_loss: 1.5005 - val_acc: 0.4468
#
# Epoch 00085: val_loss did not improve from 0.96073
# Epoch 86/100
#  - 5s - loss: 1.7565 - acc: 0.3883 - val_loss: 1.5488 - val_acc: 0.4446
#
# Epoch 00086: val_loss did not improve from 0.96073
# Epoch 87/100
#  - 5s - loss: 1.7536 - acc: 0.3894 - val_loss: 2.0553 - val_acc: 0.4400
#
# Epoch 00087: val_loss did not improve from 0.96073
# Epoch 88/100
#  - 5s - loss: 1.7716 - acc: 0.3846 - val_loss: 1.5939 - val_acc: 0.4116
#
# Epoch 00088: val_loss did not improve from 0.96073
# Epoch 89/100
#  - 5s - loss: 1.7778 - acc: 0.3798 - val_loss: 1.5765 - val_acc: 0.4544
#
# Epoch 00089: val_loss did not improve from 0.96073
# Epoch 90/100
#  - 5s - loss: 1.7727 - acc: 0.3807 - val_loss: 1.9123 - val_acc: 0.3108
#
# Epoch 00090: val_loss did not improve from 0.96073
# Epoch 91/100
#  - 5s - loss: 1.7749 - acc: 0.3799 - val_loss: 1.7135 - val_acc: 0.4304
#
# Epoch 00091: val_loss did not improve from 0.96073
# Epoch 92/100
#  - 5s - loss: 1.7806 - acc: 0.3757 - val_loss: 3.6451 - val_acc: 0.2858
#
# Epoch 00092: val_loss did not improve from 0.96073
# Epoch 93/100
#  - 5s - loss: 1.7640 - acc: 0.3844 - val_loss: 1.7694 - val_acc: 0.3976
#
# Epoch 00093: val_loss did not improve from 0.96073
# Epoch 94/100
#  - 5s - loss: 1.7777 - acc: 0.3791 - val_loss: 1.6038 - val_acc: 0.4368
#
# Epoch 00094: val_loss did not improve from 0.96073
# Epoch 95/100
#  - 5s - loss: 1.7703 - acc: 0.3855 - val_loss: 1.6082 - val_acc: 0.4084
#
# Epoch 00095: val_loss did not improve from 0.96073
# Epoch 96/100
#  - 5s - loss: 1.7838 - acc: 0.3783 - val_loss: 1.5374 - val_acc: 0.4550
#
# Epoch 00096: val_loss did not improve from 0.96073
# Epoch 97/100
#  - 5s - loss: 1.8064 - acc: 0.3714 - val_loss: 1.6650 - val_acc: 0.4232
#
# Epoch 00097: val_loss did not improve from 0.96073
# Epoch 98/100
#  - 5s - loss: 1.8077 - acc: 0.3655 - val_loss: 2.4069 - val_acc: 0.3748
#
# Epoch 00098: val_loss did not improve from 0.96073
# Epoch 99/100
#  - 5s - loss: 1.7983 - acc: 0.3721 - val_loss: 1.5105 - val_acc: 0.4650
#
# Epoch 00099: val_loss did not improve from 0.96073
# Epoch 100/100
#  - 5s - loss: 1.7838 - acc: 0.3779 - val_loss: 1.5775 - val_acc: 0.4498
#
# Epoch 00100: val_loss did not improve from 0.96073

# %%
model.load_weights('model.weights.best.hdfs')

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('\n','Test Accuracy',score[1])
# Out:
#  Test Accuracy 0.6683

# %%
y_hat = model.predict(x_test)
cifar10_labels = ['airplane','automobile','bird','cat','dog','deet','frog','horse','ship','truck']

# %%
fig = plt.figure(figsize=(20,8))
for i , idx in enumerate(np.random.choice(x_test.shape[0],size=32,replace=False)):
    ax = fig.add_subplot(4,8,i+1,xticks=[],yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{}({})".format(cifar10_labels[pred_idx],cifar10_labels[true_idx]),
    color=("green" if pred_idx == true_idx else "red"))
